# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

np.random.seed(42)
x = 2*np.random.rand(100,1)
y = 4+3*x+np.random.randn(100,1)

plt.scatter(x,y, color='blue', alpha=0.5)
plt.title('Generated data')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
print("절편 (Intercept):", model.intercept_)
print("기울기 (Coefficient):", model.coef_)
# Out:
# 절편 (Intercept): [4.21509616]
# 기울기 (Coefficient): [[2.77011339]]

# %%
x_new = np.array([[0],[2]])
y_new = model.predict(x_new)

plt.scatter(x,y, color='blue', alpha=0.5)
plt.plot(x_new, y_new, color='red', linewidth=3)
plt.title('Linear Regression')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
test_x = np.array([[1.5],[3.0]])
test_y = model.predict(test_x)

print("예측값:", test_y[0][0], test_y[1][0])
# Out:
# 예측값: 8.370266237204472 12.525436316862198
